# %%
import xml.etree.ElementTree as ET

# Load XML file
tree = ET.parse('salesforce.stackexchange.com/Posts.xml')

# Get the root element
root = tree.getroot()

# Initialize dictionaries
questions = {}
answers = {}

# Iterate over each 'row' element
for row in root.iter('row'):
    post_type_id = row.attrib.get('PostTypeId')
    if post_type_id == "1":
        # This is a question
        question_id = row.attrib.get('Id')
        title = row.attrib.get('Title')
        body = row.attrib.get('Body')
        questions[question_id] = {'title': title, 'body': body}
    elif post_type_id == "2":
        # This is an answer
        answer_id = row.attrib.get('Id')
        question_id = row.attrib.get('ParentId')
        body = row.attrib.get('Body')
        answer_dict = {'answer_id': answer_id, 'body': body}
        if question_id in answers:
            answers[question_id].append(answer_dict)
        else:
            answers[question_id] = [answer_dict]

# %%
questions

# %%
answers[]
# Out:
# {'6': [{'answer_id': '7',
#    'body': "<p>We've had long conversations with SFDC about this, no, there is no documentation to my knowledge. </p>\n\n<p>Just vague references to using it to allow API access in Group/PE.</p>\n\n<p>You can however use <code>@RemoteAction</code> annotated methods if you want to do some Ajaxy calls in your VF pages <em>(that's the way we've done it)</em> </p>\n"},
#   {'answer_id': '27',
# ...

# %%
# Install Dependencies
! pip install git+https://github.com/deepset-ai/haystack.git
! pip install urllib3==1.25.4
! pip install pandas
! pip install nltk
